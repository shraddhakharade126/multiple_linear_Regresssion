# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# import dataset

ds= pd.read_csv("multiple_linear_regression_dataset.csv")
ds
# Out:
#    Experience  Education_Level  Age  Salary
# 0           1               10   22   25000
# 1           3               12   25   30000
# 2           5               14   28   40000
# 3           7               16   30   50000
# 4           9               18   34   60000
# 5          11               12   36   52000
# 6          13               16   40   58000
# 7          15               14   42   60000
# 8          17               18   45   70000
# 9          20               20   50   80000

# %%
ds.columns
# Out:
# Index(['Experience', 'Education_Level', 'Age', 'Salary'], dtype='object')

# %%
# divide variables as independent and dependent variables

x=ds[['Experience', 'Education_Level', 'Age']]
y=ds[['Salary']]

# %%
# Out:
#    Salary
# 0   25000
# 1   30000
# 2   40000
# 3   50000
# 4   60000
# 5   52000
# 6   58000
# 7   60000
# 8   70000
# 9   80000

# %%
# spliting dataset as Training and Testing 

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state=1)

# %%
x_test
# Out:
#    Experience  Education_Level  Age
# 2           5               14   28
# 9          20               20   50

# %%
# model fitting

from sklearn.linear_model import LinearRegression
reg= LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# predict

data=[[2,12,32]]
columns =x.columns
myinput =pd.DataFrame(columns =columns ,data=data)
res =reg.predict(myinput)
res
# Out:
# array([[12623.93328161]])

# %%
y_pre =reg.predict(x_test)
y_pre
# Out:
# array([[40657.87432118],
#        [80948.60356866]])

# %%
y_test
# Out:
#    Salary
# 2   40000
# 9   80000

# %%
# checking accuracy
from sklearn.metrics import r2_score
res =r2_score(y_test,y_pre)
res
# Out:
# 0.9983341908088283

# %%
# for user input

def my_prediction():
    data =[]
    print("Enter input for feature :")
    for col in x.columns:
        value = float(input(f"Enter {col} :"))
        data.append(value)
    myinput = pd.DataFrame([data],columns=x.columns)
    res= reg.predict(myinput)
    print(f"Your salary close to : {res[0]}")

# %%
my_prediction()
# Out:
# Enter input for feature :
# Enter Experience : 2
# Enter Education_Level : 12
# Enter Age : 32
# Your salary close to : [12623.93328161]
